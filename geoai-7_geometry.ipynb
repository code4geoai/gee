# %% [markdown]
# # To check the geomertry properties of building geodataframe.

# %%
import geoai

# %%
# Loading Dataset
vector_url = "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/naip_buildings_masks.geojson"
raster_url = (
    "https://huggingface.co/datasets/giswqs/geospatial/resolve/main/naip_train.tif"
)

# %%
gdf = geoai.read_vector(vector_url)

# %%
gdf.head()
# Out:
#    confidence  class                                           geometry
# 0    0.994213      1  POLYGON ((455181.6 5277618.6, 455177.4 5277614...
# 1    0.992599      1  POLYGON ((454990.2 5277628.2, 454990.2 5277627...
# 2    0.989381      1  POLYGON ((454855.8 5277628.2, 454855.8 5277626...
# 3    0.986561      1  POLYGON ((454981.8 5277798, 454981.2 5277797.4...
# 4    0.982763      1  POLYGON ((455052 5277904.8, 455050.8 5277903.6...

# %%
geoai.view_vector_interactive(gdf,column='confidence',tiles = raster_url)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d26adf4f8be869041f47e574488ac034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d26adf4f8be869041f47e574488ac034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d26adf4f8be869041f47e574488ac034 = L.map(
#                 &quot;map_d26adf4f8be869041f47e574488ac034&quot;,
#                 {
#                     center: [47.65300113644223, -117.59214541849703],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d26adf4f8be869041f47e574488ac034);
#
#
#
#
#
#             var tile_layer_6b02b278c570dee44e4e0414fc4f4933 = L.tileLayer(
#                 &quot;https://giswqs-titiler-endpoint.hf.space/cog/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fhuggingface.co%2Fdatasets%2Fgiswqs%2Fgeospatial%2Fresolve%2Fmain%2Fnaip_train.tif\u0026bidx=1\u0026bidx=2\u0026bidx=3&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b02b278c570dee44e4e0414fc4f4933.addTo(map_d26adf4f8be869041f47e574488ac034);
#
#
#             map_d26adf4f8be869041f47e574488ac034.fitBounds(
#                 [[47.6501652204321, -117.6018194654575], [47.65583705245236, -117.58247137153656]],
#                 {}
#             );
#
#
#         function geo_json_3632a58d677cf36b2bf55e0402beb937_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#f8e621&quot;, &quot;fillColor&quot;: &quot;#f8e621&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#f6e620&quot;, &quot;fillColor&quot;: &quot;#f6e620&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#f1e51d&quot;, &quot;fillColor&quot;: &quot;#f1e51d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#efe51c&quot;, &quot;fillColor&quot;: &quot;#efe51c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#ece51b&quot;, &quot;fillColor&quot;: &quot;#ece51b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#eae51a&quot;, &quot;fillColor&quot;: &quot;#eae51a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#e7e419&quot;, &quot;fillColor&quot;: &quot;#e7e419&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#e5e419&quot;, &quot;fillColor&quot;: &quot;#e5e419&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#e2e418&quot;, &quot;fillColor&quot;: &quot;#e2e418&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#dfe318&quot;, &quot;fillColor&quot;: &quot;#dfe318&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;#dde318&quot;, &quot;fillColor&quot;: &quot;#dde318&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;:
#                     return {&quot;color&quot;: &quot;#dae319&quo

# %% [markdown]
# # Add Geometric Properties

# %%
gdf_props = geoai.add_geometric_properties(gdf,area_unit='m2',length_unit='m')

# %%
gdf_props.head()
# Out:
#    confidence  class                                           geometry  \
# 0    0.994213      1  POLYGON ((455181.6 5277618.6, 455177.4 5277614...
# 1    0.992599      1  POLYGON ((454990.2 5277628.2, 454990.2 5277627...
# 2    0.989381      1  POLYGON ((454855.8 5277628.2, 454855.8 5277626...
# 3    0.986561      1  POLYGON ((454981.8 5277798, 454981.2 5277797.4...
# 4    0.982763      1  POLYGON ((455052 5277904.8, 455050.8 5277903.6...
#
#    area_m2    length_m  perimeter_m  area_bbox_m2  area_convex_m2  \
# 0   184.50   53.407316    53.407316        241.92          189.18
# 1   527.22   92.836753    92.836753        546.84          533.52
# 2   599.40   97.988225    97.988225        617.40          604.44
# 3   741.96  129.976450   129.976450        866.52          786.24
# 4   748.98  130.122035   130.122035        876.96          795.78
#
#    area_filled_m2  major_length_m  minor_length_m  eccentricity  orientation  \
# 0          184.50            19.2            12.6      0.754544          0.0
# 1          527.22            29.4            18.6      0.774435         90.0
# 2          599.40            29.4            21.0      0.699854         90.0
# 3          741.96            49.8            17.4      0.936975          0.0
# 4          748.98            50.4            17.4      0.938515         90.0
#
#    elongation    extent  solidity  complexity
# 0    1.523810  0.762649  0.975262    1.109169
# 1    1.580645  0.964121  0.988192    1.140562
# 2    1.400000  0.970845  0.991662    1.129043
# 3    2.862069  0.856253  0.943681    1.346076
# 4    2.896552  0.854064  0.941190    1.341253

# %% [markdown]
# # Viewing buildings on columns

# %%
geoai.view_vector_interactive(gdf_props,column = "area_m2",tiles = raster_url)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d89534c9eb1ebeb89a3795c2f2ae92dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d89534c9eb1ebeb89a3795c2f2ae92dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d89534c9eb1ebeb89a3795c2f2ae92dd = L.map(
#                 &quot;map_d89534c9eb1ebeb89a3795c2f2ae92dd&quot;,
#                 {
#                     center: [47.65300113644223, -117.59214541849703],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d89534c9eb1ebeb89a3795c2f2ae92dd);
#
#
#
#
#
#             var tile_layer_282b460e7e57548a9da3ade96e9ffde0 = L.tileLayer(
#                 &quot;https://giswqs-titiler-endpoint.hf.space/cog/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fhuggingface.co%2Fdatasets%2Fgiswqs%2Fgeospatial%2Fresolve%2Fmain%2Fnaip_train.tif\u0026bidx=1\u0026bidx=2\u0026bidx=3&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_282b460e7e57548a9da3ade96e9ffde0.addTo(map_d89534c9eb1ebeb89a3795c2f2ae92dd);
#
#
#             map_d89534c9eb1ebeb89a3795c2f2ae92dd.fitBounds(
#                 [[47.6501652204321, -117.6018194654575], [47.65583705245236, -117.58247137153656]],
#                 {}
#             );
#
#
#         function geo_json_a19de148e7bef44c76ebec46a25c7498_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;6&quot;: case &quot;25&quot;: case &quot;38&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;66&quot;: case &quot;86&quot;: case &quot;97&quot;: case &quot;102&quot;: case &quot;105&quot;: case &quot;116&quot;: case &quot;118&quot;: case &quot;138&quot;: case &quot;145&quot;: case &quot;168&quot;: case &quot;179&quot;: case &quot;184&quot;: case &quot;186&quot;: case &quot;188&quot;: case &quot;198&quot;: case &quot;201&quot;: case &quot;206&quot;: case &quot;214&quot;: case &quot;216&quot;: case &quot;219&quot;: case &quot;220&quot;: case &quot;223&quot;: case &quot;226&quot;: case &quot;251&quot;: case &quot;263&quot;: case &quot;269&quot;: case &quot;287&quot;: case &quot;301&quot;: case &quot;303&quot;: case &quot;318&quot;: case &quot;321&quot;: case &quot;325&quot;: case &quot;326&quot;: case &quot;329&quot;: case &quot;336&quot;: case &quot;337&quot;: case &quot;346&quot;: case &quot;356&quot;: case &quot;358&quot;: case &quot;359&quot;: case &quot;374&quot;: case &quot;377&quot;: case &quot;384&quot;: case &quot;393&quot;: case &quot;414&quot;: case &quot;416&quot;: case &quot;424&quot;: case &quot;426&quot;: case &quot;441&quot;: case &quot;447&quot;: case &quot;470&quot;: case &quot;475&quot;: case &quot;478&quot;: case &quot;508&quot;: case &quot;512&quot;: case &quot;516&quot;: case &quot;523&quot;: case &quot;526&quot;: case &quot;527&quot;: case &quot;539&quot;: case &quot;543&quot;: case &quot;546&quot;: case &quot;559&quot;: case &quot;565&quot;: case &quot;583&quot;: case &quot;595&quot;: case &quot;613&quot;: case &quot;621&quot;: case &quot;625&quot;: case &quot;627&quot;: case &quot;640&quot;: case &quot;657&quot;: case &quot;674&quot;:
#                     return {&quot;color&quot;: &quot;#471164&quot;, &quot;fillColor&quot;: &quot;#471164&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#453581&quot;, &quot;fillColor&quot;: &quot;#453581&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#433d84&quot;, &quot;fillColor&quot;: &quot;#433d84&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#3e4a89&quot;, &quot;fillColor&quot;: &quot;#3e4a89&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#375a8c&quot;, &quot;fillColor&quot;: &quot;#375a8c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weigh

# %% [markdown]
# # Filtering based on geomertric Properties

# %%
gdf_filtered = gdf_props[(gdf_props['area_m2']<2000) & (gdf_props['elongation']< 5 ) ]

# %%
geoai.view_vector_interactive(gdf_filtered,column = "elongation",tiles = raster_url)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a08e7b6336c397b07addc2225b1e1d5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a08e7b6336c397b07addc2225b1e1d5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a08e7b6336c397b07addc2225b1e1d5a = L.map(
#                 &quot;map_a08e7b6336c397b07addc2225b1e1d5a&quot;,
#                 {
#                     center: [47.65300113644223, -117.59184212071746],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_a08e7b6336c397b07addc2225b1e1d5a);
#
#
#
#
#
#             var tile_layer_77be2af21233f5e6cae271986cdd0448 = L.tileLayer(
#                 &quot;https://giswqs-titiler-endpoint.hf.space/cog/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fhuggingface.co%2Fdatasets%2Fgiswqs%2Fgeospatial%2Fresolve%2Fmain%2Fnaip_train.tif\u0026bidx=1\u0026bidx=2\u0026bidx=3&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;TiTiler&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77be2af21233f5e6cae271986cdd0448.addTo(map_a08e7b6336c397b07addc2225b1e1d5a);
#
#
#             map_a08e7b6336c397b07addc2225b1e1d5a.fitBounds(
#                 [[47.6501652204321, -117.60121286989836], [47.65583705245236, -117.58247137153656]],
#                 {}
#             );
#
#
#         function geo_json_990a7334b027b29b746236fa9980478f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;68&quot;: case &quot;98&quot;: case &quot;117&quot;: case &quot;139&quot;: case &quot;189&quot;: case &quot;345&quot;: case &quot;451&quot;: case &quot;486&quot;: case &quot;501&quot;: case &quot;522&quot;: case &quot;681&quot;:
#                     return {&quot;color&quot;: &quot;#46307e&quot;, &quot;fillColor&quot;: &quot;#46307e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;40&quot;: case &quot;268&quot;:
#                     return {&quot;color&quot;: &quot;#453581&quot;, &quot;fillColor&quot;: &quot;#453581&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;69&quot;: case &quot;90&quot;: case &quot;169&quot;: case &quot;204&quot;: case &quot;248&quot;: case &quot;302&quot;: case &quot;357&quot;: case &quot;429&quot;: case &quot;612&quot;: case &quot;680&quot;:
#                     return {&quot;color&quot;: &quot;#482576&quot;, &quot;fillColor&quot;: &quot;#482576&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#218e8d&quot;, &quot;fillColor&quot;: &quot;#218e8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;31&quot;: case &quot;35&quot;: case &quot;353&quot;: case &quot;574&quot;:
#                     return {&quot;color&quot;: &quot;#1f968b&quot;, &quot;fillColor&quot;: &quot;#1f968b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;23&quot;: case &quot;55&quot;: case &quot;163&quot;: case &quot;190&quot;: case &quot;240&quot;: case &quot;258&quot;: case &quot;377&quot;: case &quot;414&quot;: case &quot;461&quot;: case &quot;470&quot;: case &quot;513&quot;: case &quot;628&quot;:
#                     return {&quot;color&quot;: &quot;#481c6e&quot;, &quot;fillColor&quot;: &quot;#481c6e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;29&quot;: case &quot;36&quot;: case &quot;41&quot;: case &quot;63&quot;: case &quot;74&quot;: case &quot;118&quot;: case &quot;157&quot;: case &quot;223&quot;: case &quot;516&quot;:
#                     return {&quot;color&quot;: &quot;#482878&quot;, &quot;fillColor&quot;: &quot;#482878&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     retur
