# %% [markdown]
# This notebook covers the splitting of pabbi satellite imagery into train - test split (80-20 %).
# Steps:
# - load the pabbi cog using geoai.
# - use rasterio to split pabbi cog into training testing parts.

# %%
import geoai

# %%
image_path = 'pabbi_satellite_image_COG.tif' # Path to the COG locally stored image

# %%
geoai.view_raster(image_path)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_994f631089dbce2f96bfe2c5a11058c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_994f631089dbce2f96bfe2c5a11058c9&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_994f631089dbce2f96bfe2c5a11058c9 = L.map(
#                 &quot;map_994f631089dbce2f96bfe2c5a11058c9&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_994f631089dbce2f96bfe2c5a11058c9);
#
#
#
#
#
#             var tile_layer_fa7dbfdb5146bd04c727a728776e48c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa7dbfdb5146bd04c727a728776e48c7.addTo(map_994f631089dbce2f96bfe2c5a11058c9);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_994f631089dbce2f96bfe2c5a11058c9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_11764947948383c6c210c851bfb146e8 =
#                     new L.featureGroup().addTo(
#                         map_994f631089dbce2f96bfe2c5a11058c9
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_11764947948383c6c210c851bfb146e8;
#             var draw_control_11764947948383c6c210c851bfb146e8 = new L.Control.Draw(
#                 options
#             ).addTo( map_994f631089dbce2f96bfe2c5a11058c9 );
#             map_994f631089dbce2f96bfe2c5a11058c9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_11764947948383c6c210c851bfb146e8.addLayer(layer);
#             });
#             map_994f631089dbce2f96bfe2c5a11058c9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_11764947948383c6c210c851bfb146e8.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_0b84117d2f655ac36b091879a13cca72 = geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_0b84117d2f655ac36b091879a13cca72 = L.Control.Geocoder[ geocoderName_geocoder_0b84117d2f655ac36b091879a13cca72 ](
#                 geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72[&quot;geocoder&quot;] = customGeocoder_geocoder_0b84117d2f655ac36b091879a13cca72;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_0b84117d2f655ac36b091879a13cca72[&#x27;zoom&#x27;] || map_994f631089dbce2f96bfe2c5a11058c9.getZoom();
#                 map_994f631089dbce2f96bfe2c5a11058c9.setView(e.geocode.center, zoom);
#             }).addTo(map_994f631089dbce2f96bfe2c5a11058c9);
#
#
#
#             map_994

# %% [markdown]
# # Part 2
# Using Rasterio to create training testing split.

# %%
import rasterio

# %%
import rasterio
from rasterio.windows import Window

image_path = "pabbi_satellite_image_COG.tif"
train_path = "train_image.tif"
test_path = "test_image.tif"

with rasterio.open(image_path) as src:
    width = src.width
    height = src.height
    count = src.count
    dtype = src.dtypes[0]
    crs = src.crs

    split_width = int(0.8 * width)

    # Prepare window definitions
    train_window = Window(0, 0, split_width, height)
    test_window = Window(split_width, 0, width - split_width, height)

    # Define shared profile updates (compression + tiling)
    profile = src.profile.copy()
    common_updates = {
        'compress': 'lzw',
        'tiled': True,
        'blockxsize': 512,
        'blockysize': 512,
        'interleave': 'band',  # safer than 'pixel' for writing per band
        'predictor': 2,
        'BIGTIFF': 'IF_SAFER'  # allow large TIFFs if needed
    }

    # ---------------- WRITE TRAIN ----------------
    train_profile = profile.copy()
    train_profile.update({
        'width': train_window.width,
        'height': train_window.height,
        'transform': src.window_transform(train_window),
        **common_updates
    })

    with rasterio.open(train_path, 'w', **train_profile) as dst:
        for i in range(1, count + 1):
            band = src.read(i, window=train_window)
            dst.write(band, i)

    # ---------------- WRITE TEST ----------------
    test_profile = profile.copy()
    test_profile.update({
        'width': test_window.width,
        'height': test_window.height,
        'transform': src.window_transform(test_window),
        **common_updates
    })

    with rasterio.open(test_path, 'w', **test_profile) as dst:
        for i in range(1, count + 1):
            band = src.read(i, window=test_window)
            dst.write(band, i)

# %%
geoai.view_raster('test20.tif')
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36e8ef23aa821cf98d0e17b932ba4389 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36e8ef23aa821cf98d0e17b932ba4389&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36e8ef23aa821cf98d0e17b932ba4389 = L.map(
#                 &quot;map_36e8ef23aa821cf98d0e17b932ba4389&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_36e8ef23aa821cf98d0e17b932ba4389);
#
#
#
#
#
#             var tile_layer_8a19ccf700781bf1a2494f8169860a17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a19ccf700781bf1a2494f8169860a17.addTo(map_36e8ef23aa821cf98d0e17b932ba4389);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_36e8ef23aa821cf98d0e17b932ba4389);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_b67457568d2a5f85f1dae5b4c1708652 =
#                     new L.featureGroup().addTo(
#                         map_36e8ef23aa821cf98d0e17b932ba4389
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_b67457568d2a5f85f1dae5b4c1708652;
#             var draw_control_b67457568d2a5f85f1dae5b4c1708652 = new L.Control.Draw(
#                 options
#             ).addTo( map_36e8ef23aa821cf98d0e17b932ba4389 );
#             map_36e8ef23aa821cf98d0e17b932ba4389.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_b67457568d2a5f85f1dae5b4c1708652.addLayer(layer);
#             });
#             map_36e8ef23aa821cf98d0e17b932ba4389.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_b67457568d2a5f85f1dae5b4c1708652.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_8c676102de3f2703bfcce5ff07e42ade = geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_8c676102de3f2703bfcce5ff07e42ade = L.Control.Geocoder[ geocoderName_geocoder_8c676102de3f2703bfcce5ff07e42ade ](
#                 geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade[&quot;geocoder&quot;] = customGeocoder_geocoder_8c676102de3f2703bfcce5ff07e42ade;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_8c676102de3f2703bfcce5ff07e42ade[&#x27;zoom&#x27;] || map_36e8ef23aa821cf98d0e17b932ba4389.getZoom();
#                 map_36e8ef23aa821cf98d0e17b932ba4389.setView(e.geocode.center, zoom);
#             }).addTo(map_36e8ef23aa821cf98d0e17b932ba4389);
#
#
#
#             map_36e

# %%
geoai.view_raster('train80.tif')
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1649ccd3c8423a2ab8b63ef0955b7b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1649ccd3c8423a2ab8b63ef0955b7b1&quot; &gt;&lt;/div&gt;
#
#
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1649ccd3c8423a2ab8b63ef0955b7b1 = L.map(
#                 &quot;map_b1649ccd3c8423a2ab8b63ef0955b7b1&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_b1649ccd3c8423a2ab8b63ef0955b7b1);
#
#
#
#
#
#             var tile_layer_ba5c1781cf11c94e2e38579e33aa6c14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba5c1781cf11c94e2e38579e33aa6c14.addTo(map_b1649ccd3c8423a2ab8b63ef0955b7b1);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_b1649ccd3c8423a2ab8b63ef0955b7b1);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#                 // FeatureGroup is to store editable layers.
#                 var drawnItems_draw_control_b40c755e7d15ba00fbfb4cc13c87a16e =
#                     new L.featureGroup().addTo(
#                         map_b1649ccd3c8423a2ab8b63ef0955b7b1
#                     );
#
#             options.edit.featureGroup = drawnItems_draw_control_b40c755e7d15ba00fbfb4cc13c87a16e;
#             var draw_control_b40c755e7d15ba00fbfb4cc13c87a16e = new L.Control.Draw(
#                 options
#             ).addTo( map_b1649ccd3c8423a2ab8b63ef0955b7b1 );
#             map_b1649ccd3c8423a2ab8b63ef0955b7b1.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems_draw_control_b40c755e7d15ba00fbfb4cc13c87a16e.addLayer(layer);
#             });
#             map_b1649ccd3c8423a2ab8b63ef0955b7b1.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems_draw_control_b40c755e7d15ba00fbfb4cc13c87a16e.addLayer(e.layer);
#             });
#
#
#
#
#
#             var geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042 = {
#   &quot;collapsed&quot;: true,
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;defaultMarkGeocode&quot;: true,
#   &quot;zoom&quot;: 11,
#   &quot;provider&quot;: &quot;nominatim&quot;,
#   &quot;providerOptions&quot;: {
# },
# };
#
#             // note: geocoder name should start with lowercase
#             var geocoderName_geocoder_a6040c3a37238e7b3b7f26f26bd6d042 = geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042[&quot;provider&quot;];
#
#             var customGeocoder_geocoder_a6040c3a37238e7b3b7f26f26bd6d042 = L.Control.Geocoder[ geocoderName_geocoder_a6040c3a37238e7b3b7f26f26bd6d042 ](
#                 geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042[&#x27;providerOptions&#x27;]
#             );
#             geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042[&quot;geocoder&quot;] = customGeocoder_geocoder_a6040c3a37238e7b3b7f26f26bd6d042;
#
#             L.Control.geocoder(
#                 geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 var zoom = geocoderOpts_geocoder_a6040c3a37238e7b3b7f26f26bd6d042[&#x27;zoom&#x27;] || map_b1649ccd3c8423a2ab8b63ef0955b7b1.getZoom();
#                 map_b1649ccd3c8423a2ab8b63ef0955b7b1.setView(e.geocode.center, zoom);
#             }).addTo(map_b1649ccd3c8423a2ab8b63ef0955b7b1);
#
#
#
#             map_b16
